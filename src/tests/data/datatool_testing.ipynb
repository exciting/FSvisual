# %%
import numpy as np
from fsvisual.input import read_energy_numbers

df, fermi_energy, rez_base_vect, grid_size=read_energy_numbers("/home/Jan/PycharmProjects/FSvisual/src/tests/data/bxsf/fcc_41x41x41.bxsf")

np.savez(
    "/home/Jan/PycharmProjects/FSvisual/src/tests/data/npz/expected_fcc_41x41x41.npz",
    df=df,
    fermi_energy=fermi_energy,
    rez_base_vect=rez_base_vect,
    grid_size=grid_size[0]
)
